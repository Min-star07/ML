# %%
from matplotlib import pyplot as plt
import numpy as np
import torch

torch.manual_seed(123)

# %%
from torchvision import datasets

data_path = "../lesson3/dataset"
cifar10 = datasets.CIFAR10(data_path, train=True, download=True)
cifar10 = datasets.CIFAR10(data_path, train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class_names = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
]
fig = plt.figure(figsize=(8, 3))

num_class = 10
for i in range(num_class):
    ax = fig.add_subplot(2, 5, i + 1, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    img = next(img for img, label in cifar10 if label == i)
    plt.imshow(img)

# %%
type(cifar10).__mro__
# Out:
# (torchvision.datasets.cifar.CIFAR10,
#  torchvision.datasets.vision.VisionDataset,
#  torch.utils.data.dataset.Dataset,
#  typing.Generic,
#  object)

# %%
len(cifar10)
# Out:
# 10000

# %%
img, label = cifar10[99]
img, label, class_names[label]
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>, 7, 'horse')

# %%
plt.imshow(img)

# %%
from torchvision import transforms

dir(transforms)
# Out:
# ['AugMix',
#  'AutoAugment',
#  'AutoAugmentPolicy',
#  'CenterCrop',
#  'ColorJitter',
#  'Compose',
#  'ConvertImageDtype',
#  'ElasticTransform',
#  'FiveCrop',
#  'GaussianBlur',
#  'Grayscale',
#  'InterpolationMode',
#  'Lambda',
#  'LinearTransformation',
#  'Normalize',
#  'PILToTensor',
#  'Pad',
#  'RandAugment',
#  'RandomAdjustSharpness',
#  'RandomAffine',
#  'RandomApply',
#  'RandomAutocontrast',
#  'RandomChoice',
#  'RandomCrop',
#  'RandomEqualize',
#  'RandomErasing',
#  'RandomGrayscale',
#  'RandomHorizontalFlip',
#  'RandomInvert',
#  'RandomOrder',
#  'RandomPerspective',
#  'RandomPosterize',
#  'RandomResizedCrop',
#  'RandomRotation',
#  'RandomSolarize',
#  'RandomVerticalFlip',
#  'Resize',
#  'TenCrop',
#  'ToPILImage',
#  'ToTensor',
#  'TrivialAugmentWide',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_functional_pil',
#  '_functional_tensor',
# ...

# %%
from torchvision import transforms

to_tensor = transforms.ToTensor()
img_t = to_tensor(img)
img_t.shape
# Out:
# torch.Size([3, 32, 32])

# %%
tensor_cirar10 = datasets.CIFAR10(
    data_path, train=True, download=True, transform=transforms.ToTensor()
)

img_t, _ = tensor_cirar10[99]
type(img_t)
# Out:
# Files already downloaded and verified
# torch.Tensor

# %%
img_t.shape, img_t.type
# Out:
# (torch.Size([3, 32, 32]), <function Tensor.type>)

# %%
img_t.min(), img_t.max()
# Out:
# (tensor(0.), tensor(1.))

# %%
plt.imshow(img_t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.imshow(img_t)
#
# File ~/Software/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3325 @_copy_docstring_and_deprecators(Axes.imshow)
#    3326 def imshow(
#    3327     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3344     **kwargs,
#    3345 ) -> AxesImage:
# -> 3346     __ret = gca().imshow(
#    3347         X,
#    3348         cmap=cmap,
#    3349         norm=norm,
#    3350         aspect=aspect,
#    3351         interpolation=interpolation,
#    3352         alpha=alpha,
#    3353         vmin=vmin,
#    3354         vmax=vmax,
#    3355         origin=origin,
#    3356         extent=extent,
# ...

# %%
plt.imshow(img_t.permute(1, 2, 0))

# %%
imgs = torch.stack([img_t for img_t, _ in tensor_cirar10], dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
imgs.view(3, -1).mean(dim=1)
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %%
imgs.view(3, -1).std(dim=1)
# Out:
# tensor([0.2470, 0.2435, 0.2616])

# %%
transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616))
# Out:
# Normalize(mean=(0.4915, 0.4823, 0.4468), std=(0.247, 0.2435, 0.2616))

# %%
transformed_cifar10 = datasets.CIFAR10(
    data_path,
    train=True,
    download=True,
    transform=transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616)),
        ]
    ),
)
# Out:
# Files already downloaded and verified

# %%
transformed_cifar10_test = datasets.CIFAR10(
    data_path,
    train=False,
    download=True,
    transform=transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616)),
        ]
    ),
)
# Out:
# Files already downloaded and verified

# %%
img_t, _ = transformed_cifar10[99]
plt.imshow(img_t.permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
